# %% [markdown]
# # Linear Regression Modeling:

# %%
import numpy as np
import pandas as pd
import patsy

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.cross_validation import cross_val_score

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
white = pd.read_csv('/Users/divyasusarla/Desktop/DSI-SF-2-divyasusarla/Capstone/LDA_analysis/white_formodel.csv', encoding='utf8')

# %%
del white['Unnamed: 0']
white.head()
# Out:
#    wine_index                  white_wine white_wineries  white_regions  \
# 0           0  Chardonnay Hudson Vineyard    Patz & Hall  Sonoma County
# 1           0  Chardonnay Hudson Vineyard    Patz & Hall  Sonoma County
# 2           0  Chardonnay Hudson Vineyard    Patz & Hall  Sonoma County
# 3           0  Chardonnay Hudson Vineyard    Patz & Hall  Sonoma County
# 4           0  Chardonnay Hudson Vineyard    Patz & Hall  Sonoma County
#
#   white_countries  white_avg_wine_ratings  white_avg_price  vintage_year  \
# 0   United States                     4.0            54.99           NaN
# 1   United States                     4.0            54.99           NaN
# 2   United States                     4.0            54.99           NaN
# 3   United States                     4.0            54.99           NaN
# 4   United States                     4.0            54.99           NaN
#
#    review_index         white_user      ...            t18       t19  \
# 0           0.0        Alyssa Rapp      ...       0.260000  0.010000
# 1           1.0        Sam Hovland      ...       0.346667  0.013333
# 2           2.0        Jon Walheim      ...       0.020000  0.020000
# 3           3.0  Jonathan Williams      ...       0.208000  0.208000
# 4           4.0        Glenn Adams      ...       0.013333  0.013333
#
#         t20       t21       t22       t23       t24       t25  max_prob  \
# 0  0.010000  0.010000  0.010000  0.260000  0.010000  0.010000       t23
# 1  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333        t6
# 2  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000       t11
# 3  0.000000  0.208000  0.000000  0.000000  0.000000  0.000000       t19
# 4  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333        t8
#
#    unique_probs
# 0           4.0
# 1           3.0
# 2           2.0
# 3           5.0
# 4           4.0
#
# [5 rows x 38 columns]

# %%
def correlation_heat_map(self):
    corrs = white.corr()

    fig, ax = plt.subplots(figsize=(10, 8))

    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    ax = sns.heatmap(corrs, mask=mask)

    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=70)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)

    plt.show()

# %%
correlation_heat_map(white)

# %%
white.dropna(inplace=True)

# %% [markdown]
# # Linear Regression: Target is wine price

# %%
# Remove outliers on price, there were a few above 900 that impacted the model. 
white_no_outliers = white[white['white_avg_price'] < 900]

# %%
white_no_outliers
# Out:
#        wine_index                   white_wine      white_wineries  \
# 37             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 38             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 39             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 40             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 41             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 42             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 43             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 44             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 45             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 46             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 47             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 48             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 49             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 50             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 51             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 52             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 53             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 54             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 55             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 56             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 57             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 58             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 59             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 60             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 61             12  Beyond Sauvignon Blanc 2014  Buitenverwachting
# 88             24      Vermentino Toscana 2015         Aia Vecchia
# 89             24      Vermentino Toscana 2015         Aia Vecchia
# 90             24      Vermentino Toscana 2015         Aia Vecchia
# 91             24      Vermentino Toscana 2015         Aia Vecchia
# 92             24      Vermentino Toscana 2015         Aia Vecchia
# ...           ...                          ...                 ...
# 47700        9812        Berg Schlossberg 2010        Georg Breuer
# 47701        9812        Berg Schlossberg 2010        Georg Breuer
# 47702        9812        Berg Schlossberg 2010        Georg Breuer
# 47703        9812        Berg Schlossberg 2010        Georg Breuer
# 47704        9812        Berg Schlossberg 2010        Georg Breuer
# 47705        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47706        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47707        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47708        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47709        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47710        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47711        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47712        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47713        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 47714        9815       Basa Blanco Rueda 2012     Telmo Rodriguez
# 
# 39           2014.0           2.0               Cassell      ...
# 40           2014.0           3.0              DRHelter      ...
# 41           2014.0           4.0                   HCC      ...
# 42           2014.0           5.0                 Joe D      ...
# 43           2014.0           6.0               KingMob      ...
# 44           2014.0           7.0       Tristan Semmens      ...
# 45           2014.0           8.0           Sam Hovland      ...
# 46           2014.0           9.0       Pete Leisenring      ...
# 47           2014.0          10.0           Jean Daigle      ...
# 48           2014.0          11.0           Linka Preus      ...
# 49           2014.0          12.0        Tony Cipollone      ...
# 50           2014.0          13.0      Chris Chichester      ...
# 51           2014.0          14.0          Marc Forrest      ...
# 52           2014.0          15.0         Nathan Anibas      ...
# 53           2014.0          16.0        Nicole Sargent      ...
# 54           2014.0          17.0       Dave Livingston      ...
# 55           2014.0          18.0       Jen DeMagistris      ...
# 56           2014.0          19.0    Cara Franey Muglia      ...
# 57           2014.0          20.0       Shani Collymore      ...
# 58           2014.0          21.0          Simon Brauer      ...
# 59           2014.0          22.0           Lisa Weller      ...
# 60           2014.0          23.0      Katherine Harmon      ...
# 61           2014.0          24.0               Susan G      ...
# 88           2015.0           0.0           John Costin      ...
# 89           2015.0           2.0         Trent Perkins      ...
# 90           2015.0           3.0      The Wine Stalker      ...
# 91           2015.0           4.0           Tim Cornine      ...
# 92           2015.0           5.0                 Jen B      ...
# ...             ...           ...                   ...      ...
# 47700        2010.0           8.0                Vera I      ...
# 47701        2010.0           9.0           Jeff Fortin      ...
# 47702        2010.0          10.0                Vera I      ...
# 47703        2010.0          11.0        Martin Kouprie      ...
# 47704        2010.0          12.0           Steve Alley      ...
# 47705        2012.0           0.0              Robert E      ...
# 47706        2012.0           1.0               Artigas      ...
# 47707        2012.0           2.0               Susan A      ...
# 47708        2012.0           3.0           Tim Cornine      ...
# 47709        2012.0           4.0        Liliana Cabana      ...
# 47710        2012.0           5.0            Ken Kasper      ...
# 47711        2012.0           6.0      Kerstin Kothrade      ...
# 47712        2012.0           7.0           Dave Morris      ...
# 47713        2012.0           8.0          Mr. Pedersen      ...
# 47714        2012.0           9.0          Erin Jurnove      ...
# 47715        2012.0          10.0          Trina Warman      ...
# 47716        2012.0          11.0         Darien gibson      ...
# 47717        2012.0          12.0              Tom Wade      ...
# 47718        2012.0          13.0                   Don      ...
# 47719        2012.0          14.0            Asa Joseph      ...
# 47720        2012.0          15.0             Michael P      ...
# 47721        2012.0          16.0         Will The Phil      ...
# 47722        2012.0          17.0           Ross Harvey      ...
# 47723        2012.0          18.0            Chris Lake      ...
# 47724        2012.0          19.0  Taylor Cole Longacre      ...
# 47725        2012.0          20.0        Julien Jacquet      ...
# 47726        2012.0          21.0           Debra Davis      ...
# 47727        2012.0          22.0            Karen Benz      ...
# 47728        2012.0          23.0        Angela Coffman      ...
# 47729        2012.0          24.0         Diane Heyboer      ...
#
#             t18       t19       t20       t21       t22       t23       t24  \
# 37     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.130000
# 38     0.458182  0.094545  0.000000  0.000000  0.000000  0.000000  0.000000
# 39     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 40     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 41     0.013333  0.013333  0.346667  0.013333  0.013333  0.013333  0.013333
# 42     0.020000  0.020000  0.020000  0.020000  0.520000  0.020000  0.020000
# 43     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 44     0.000000  0.000000  0.173333  0.000000  0.000000  0.000000  0.000000
# 45     0.000000  0.173333  0.173333  0.000000  0.000000  0.000000  0.000000
# 46     0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47     0.013333  0.013333  0.013333  0.013333  0.346667  0.013333  0.013333
# 48     0.156923  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 49     0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333
# 50     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 51     0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.520000
# 52     0.000000  0.000000  0.577143  0.000000  0.000000  0.000000  0.000000
# 53     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 54     0.260000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 55     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 56     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 57     0.010000  0.010000  0.010000  0.260000  0.260000  0.010000  0.010000
# 58     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 59     0.000000  0.000000  0.000000  0.000000  0.340000  0.173333  0.000000
# 60     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 61     0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 88     0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333
# 89     0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 90     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 91     0.020000  0.020000  0.020000  0.020000  0.520000  0.020000  0.020000
# 92     0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# ...         ...       ...       ...       ...       ...       ...       ...
# 47700  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47701  0.208000  0.000000  0.208000  0.000000  0.000000  0.000000  0.000000
# 47702  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47703  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47704  0.013333  0.013333  0.013333  0.013333  0.013333  0.346667  0.013333
# 47705  0.020000  0.020000  0.020000  0.020000  0.020000  0.520000  0.020000
# 47706  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47707  0.000000  0.000000  0.510000  0.000000  0.000000  0.000000  0.000000
# 47708  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47709  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47710  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47711  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 47712  0.000000  0.000000  0.000000  0.000000  0.000000  0.408000  0.000000
# 47713  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47714  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333
# 47715  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333
# 47716  0.013333  0.013333  0.013333  0.346667  0.013333  0.013333  0.013333
# 47717  0.520000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47718  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47719  0.020000  0.020000  0.020000  0.020000  0.520000  0.020000  0.020000
# 47720  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47721  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47722  0.013333  0.013333  0.346667  0.013333  0.013333  0.013333  0.013333
# 47723  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47724  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47725  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000  0.040000
# 47726  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000  0.020000
# 47727  0.000000  0.000000  0.104000  0.000000  0.104000  0.000000  0.104000
# 47728  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333
# 47729  0.013333  0.013333  0.013333  0.013333  0.013333  0.013333  0.346667
#
#             t25  max_prob  unique_probs
# 37     0.000000       t10           6.0
# 38     0.000000       t18           7.0
# 39     0.040000        t1           1.0
# 40     0.040000        t1           1.0
# 41     0.013333       t20           3.0
# 42     0.020000       t22           2.0
# 43     0.040000        t1           1.0
# 44     0.000000        t3           5.0
# 45     0.000000        t6           5.0
# 46     0.020000        t6           2.0
# 47     0.013333       t17           3.0
# 48     0.000000       t18          10.0
# 49     0.013333       t10           2.0
# 50     0.040000        t1           1.0
# 51     0.020000       t24           2.0
# 52     0.000000       t20           4.0
# 53     0.040000        t1           1.0
# 54     0.000000        t1           4.0
# 55     0.040000        t1           1.0
# 56     0.040000        t1           1.0
# 57     0.010000       t21           4.0
# 58     0.040000        t1           1.0
# 59     0.000000       t22           4.0
# 60     0.040000        t1           1.0
# 61     0.020000        t8           2.0
# 88     0.013333        t6           2.0
# 89     0.020000       t14           2.0
# 90     0.000000        t5           4.0
# 91     0.020000       t22           2.0
# 92     0.040000        t1           1.0
# ...         ...       ...           ...
# 47700  0.040000        t1           1.0
# 47701  0.000000       t11           4.0
# 47702  0.040000        t1           1.0
# 47703  0.040000        t1           1.0
# 47704  0.013333        t2           3.0
# 47705  0.020000       t23           2.0
# 47706  0.020000        t2           2.0
# 47707  0.000000       t20           3.0
# 47708  0.040000        t1           1.0
# 47709  0.040000        t1           1.0
# 47710  0.020000        t1           2.0
# 47711  0.408000       t25           4.0
# 47712  0.000000       t23           4.0
# 47713  0.040000        t1           1.0
# 47714  0.013333        t9           3.0
# 47715  0.013333        t1           3.0
# 47716  0.013333       t21           3.0
# 47717  0.020000       t18           2.0
# 47718  0.040000        t1           1.0
# 47719  0.020000       t22           2.0
# 47720  0.020000        t8           2.0
# 47721  0.040000        t1           1.0
# 47722  0.013333        t6           3.0
# 47723  0.040000        t1           1.0
# 47724  0.040000        t1           1.0
# 47725  0.040000        t1           1.0
# 47726  0.020000        t9           2.0
# 47727  0.000000        t6           9.0
# 47728  0.013333        t7           3.0
# 47729  0.013333        t3           3.0
#
# [34017 rows x 38 columns]

# %%
y = white_no_outliers.white_avg_price.values
X = white_no_outliers.iloc[:,11:36]

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
Xn = ss.fit_transform(X)

# %%
linreg = LinearRegression()

linreg_scores = cross_val_score(linreg, Xn, y, cv=10)

print linreg_scores
print np.mean(linreg_scores)
# Out:
# [-0.01355541 -0.01241275 -0.00857627 -0.0112022  -0.00174399 -0.00578579
#  -0.00693337 -0.00265833 -0.00219867 -0.00486463]
# -0.00699314319349

# %%
from sklearn.cross_validation import train_test_split

trainX, testX, trainY, testY = train_test_split(Xn, y, train_size=0.7)
print trainX.shape, testX.shape
print trainY.shape, testY.shape
# Out:
# (23811, 25) (10206, 25)
# (23811,) (10206,)

# %%
linreg_scores = cross_val_score(linreg, trainX, trainY, cv=10)
print linreg_scores
# Out:
# [-0.00351332 -0.00117803 -0.00305258 -0.00293499 -0.00279257  0.00060945
#  -0.00225866 -0.00364398 -0.00206235 -0.00121938]

# %%
# Assign lm as the LinearRegression function
lm = LinearRegression()
# Fits trainX and trainY with the lm model and assigns to a variable
model = lm.fit(trainX, trainY)
# Returns Predicted Y values
predictions = model.predict(testX)
# R-squared
score = model.score(testX, testY)
print score
# Out:
# -0.000317522198302

# %%
# Plots your True Y with Predicted Y
fig = plt.figure(figsize=(15,5))
ax = fig.gca()
plt.scatter(testY, predictions, c='green')
ax.set_xlabel('True Y')
ax.set_ylabel('Predictions')

# %%
lm_resids = y - model.predict(Xn)

# %%
# fig, axarr = plt.bar(1, 2, figsize=(18, 6))

# sns.distplot(lm_resids, bins=50, hist=True, kde=False, 
#              color='steelblue', ax=axarr[0], label='Linear Residuals')

# plt.show()

# %%
plt.scatter(white_no_outliers.white_avg_price, white_no_outliers.white_avg_wine_ratings)

# %% [markdown]
# # Linear regression: Target is wine ratings

# %%
y = white.white_avg_wine_ratings.values
X = white.iloc[:,11:36]

ss = StandardScaler()
Xn = ss.fit_transform(X)

trainX, testX, trainY, testY = train_test_split(Xn, y, train_size=0.7)
print trainX.shape, testX.shape
print trainY.shape, testY.shape
# Out:
# (23912, 25) (10249, 25)
# (23912,) (10249,)

# %%
# Assign lm as the LinearRegression function
lm = LinearRegression()
# Fits trainX and trainY with the lm model and assigns to a variable
model = lm.fit(trainX, trainY)
# Returns Predicted Y values
predictions = model.predict(testX)
# R-squared
score = model.score(testX, testY)
print score
# Out:
# -0.00141997533214

# %%
# Plots your True Y with Predicted Y
fig = plt.figure(figsize=(15,5))
ax = fig.gca()
plt.scatter(testY, predictions, c='green')
ax.set_xlabel('True Y')
ax.set_ylabel('Predictions')
